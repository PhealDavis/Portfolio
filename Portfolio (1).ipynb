# %%
# %pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('listings.csv')
# Out:
# <ipython-input-53-47b925cf68a2>:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('listings.csv')

# %%
df.isnull()
# Out:
#           id   name  host_id  host_name  host_since  host_response_time  \
# 0      False  False    False      False       False               False
# 1      False  False    False      False       False                True
# 2      False  False    False      False       False               False
# 3      False  False    False      False       False               False
# 4      False  False    False      False       False               False
# ...      ...    ...      ...        ...         ...                 ...
# 45528  False  False    False      False       False                True
# 45529  False  False    False      False       False                True
# 45530  False  False    False      False       False               False
# 45531  False  False    False      False       False               False
# 45532  False  False    False      False       False               False
#
#        host_response_rate  host_is_superhost  neighbourhood_cleansed  \
# ...

# %%
df = df.fillna(0)

# %%
df = pd.read_csv('listings.csv', usecols=['price', 'bedrooms', 'number_of_reviews', 'availability_365'])

# %%
df = df.dropna()

# %%
average_price_per_bedroom = df.groupby('bedrooms')['price'].mean()
print(average_price_per_bedroom)
# Out:
# bedrooms
# 0.0       144.441187
# 1.0       145.100879
# 2.0       251.779602
# 3.0       411.425914
# 4.0       658.420492
# 5.0      1054.154858
# 6.0      1676.026163
# 7.0      2795.403361
# 8.0      3401.822222
# 9.0      4588.304348
# 10.0     1503.888889
# 11.0     2903.000000
# 12.0     3016.800000
# 13.0     3010.000000
# 14.0      260.000000
# 16.0    10000.000000
# 18.0      455.500000
# 19.0      200.000000
# 23.0      120.000000
# 24.0     1900.000000
# 50.0      150.000000
# Name: price, dtype: float64

# %%
# Calculate the average price per bedroom
average_price_per_bedroom = df.groupby('bedrooms')['price'].mean()

# Create a scatter plot
plt.figure(figsize=(8, 6))  # Set the figure size
plt.scatter(average_price_per_bedroom.index, average_price_per_bedroom.values, color='blue', alpha=0.7)

# Add labels and title
plt.title('Average Price per Bedroom')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Average Price')

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create scatter plot
plt.figure(figsize=(8, 6))  # Set the figure size
plt.scatter(df['availability_365'], df['price'], color='blue', alpha=0.5)

# Add labels and title
plt.title('Availability vs Price')
plt.xlabel('Availability (Days)')
plt.ylabel('Price')

# Show plot
plt.show()

# %%
#Data suggests a lower price doesn't always indicate availability will be low. Maintaining lower operating costs should be the main goal!
